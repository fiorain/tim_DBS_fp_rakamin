# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from imblearn import over_sampling
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report
import jinja2
from pycaret.classification import *
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\fiori\\OneDrive\\Desktop\\Data Final Project - Rakamin\\stage 2\\df_preprocessing_final_project.csv')

# %%
df.sample(5)
# Out:
#        Unnamed: 0  age  balance  day  duration  campaign  previous  y  \
# 39185       39185   47      306   20        20         2         0  0
# 8334         8334   28     5474   28       486         5         0  1
# 42926       42926   38     7005   25       696         1         2  1
# 78             78   46     1527    6       269         1         0  0
# 13915       13915   33     1234    9        61         1         0  0
#
#        marital_divorced  marital_married  marital_single  education_primary  \
# 39185                 0                1               0                  0
# 8334                  0                0               1                  0
# 42926                 0                1               0                  1
# 78                    0                0               1                  0
# 13915                 0                1               0                  0
#
#        education_secondary  education_tertiary  education_unknown  default_no  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           45211 non-null  int64
#  1   age                  45211 non-null  int64
#  2   balance              45211 non-null  int64
#  3   day                  45211 non-null  int64
#  4   duration             45211 non-null  int64
#  5   campaign             45211 non-null  int64
#  6   previous             45211 non-null  int64
#  7   y                    45211 non-null  int64
#  8   marital_divorced     45211 non-null  int64
#  9   marital_married      45211 non-null  int64
#  10  marital_single       45211 non-null  int64
#  11  education_primary    45211 non-null  int64
#  12  education_secondary  45211 non-null  int64
#  13  education_tertiary   45211 non-null  int64
#  14  education_unknown    45211 non-null  int64
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
month_map = {'q1':0, 'q2':1, 'q3':2, 'q4':3}

df['month_segment'] = df['month_segment'].map(month_map)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  45211 non-null  int64
#  1   balance              45211 non-null  int64
#  2   day                  45211 non-null  int64
#  3   duration             45211 non-null  int64
#  4   campaign             45211 non-null  int64
#  5   previous             45211 non-null  int64
#  6   y                    45211 non-null  int64
#  7   marital_divorced     45211 non-null  int64
#  8   marital_married      45211 non-null  int64
#  9   marital_single       45211 non-null  int64
#  10  education_primary    45211 non-null  int64
#  11  education_secondary  45211 non-null  int64
#  12  education_tertiary   45211 non-null  int64
#  13  education_unknown    45211 non-null  int64
#  14  default_no           45211 non-null  int64
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop(columns=['y']), df['y'], test_size=0.2, random_state=42)

# %%
x_smote, y_smote = over_sampling.SMOTE(random_state=42).fit_resample(x_train, y_train)

# %%
print('Original')
print(pd.Series(y_train).value_counts())
print('\nSMOTE')
print(pd.Series(y_smote).value_counts())
# Out:
# Original
# 0    31930
# 1     4238
# Name: y, dtype: int64
#
# SMOTE
# 0    31930
# 1    31930
# Name: y, dtype: int64

# %%
# initialize setup
s = setup(df, 
          target = 'y', 
          train_size = 0.8,
          fix_imbalance = True,
          numeric_features = df.drop('y', axis=1).columns.tolist(),
          imputation_type='iterative',
          fold_shuffle=True)
# Out:
# <style type="text/css">
# #T_6037d_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6037d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6037d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6037d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6037d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6037d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_6037d_row0_col1" class="data row0 col1" >5753</td>
#     </tr>
#     <tr>
#       <th id="T_6037d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6037d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6037d_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_6037d_level0_row2" class="row_heading level0 row2" >2</th>
# ...
